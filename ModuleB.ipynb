# %% [markdown]
# <a href="https://colab.research.google.com/github/gstanwoo/MAT421HW/blob/main/ModuleB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 17.2: Linear Interpolation

# %% [markdown]
# Example plot using linear interpolation:

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
x = [0, 1, 2, 3, 4]
y = [1, 3, 1, 2, 1]

f = interp1d(x, y)
y_hat = f(1.5)
plt.figure(figsize = (10,8))
plt.plot(x, y, '-ob')
plt.plot(1.5, y_hat, 'ro')
plt.title('Linear Interpolation at x = 1.5')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # Section 17.3: Cubic Spline Interpolation

# %% [markdown]
# Example of rounding error:

# %%
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')

x = [0, 1, 2, 3, 4]
y = [1, 3, 1, 2, 1]

f = CubicSpline(x, y, bc_type='natural')
x_new = np.linspace(0, 4, 100)
y_new = f(x_new)

plt.figure(figsize = (10,8))
plt.plot(x_new, y_new, 'b')
plt.plot(x, y, 'ro')
plt.title('Cubic Spline Interpolation')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
